# %%
# Install the PyDrive wrapper & import libraries.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

file_id = "1hUcoairxxbgD5rCh9HBxShoDMWKlux0b"
downloaded = drive.CreateFile({'id': file_id})

# https://drive.google.com/open?id=1hUcoairxxbgD5rCh9HBxShoDMWKlux0b

# %%
# Download the file to a local disk as 'exported.xlsx'.
downloaded.GetContentFile('exported.xlsx')

# %%
# Here it is --
# !ls -lha exported.xlsx
# Out:
# -rw-r--r-- 1 root root 9.0K Aug 18 07:11 exported.xlsx

# %%
# Now, we can use pandas read_excel after installing the excel importer.
# !pip install -q xlrd

import pandas as pd
dataset = pd.read_excel('exported.xlsx')

# %%
for i in range(len(dataset.Name)):
    if(dataset["Year"][i]==str("3rd") or dataset["Year"][i]==str("4th") ):
        name= (dataset.Name[i].lower())
        mail= (dataset.Email[i].lower())
        firstname=name.split(' ')[0]
        lastname=name.split(' ')[len(name.split(' '))-1]
        if(lastname==''):
            lastname=name.split(' ')[len(name.split(' '))-2]
        x=mail.find(firstname)
        y=mail.find(lastname)
        if (x!= -1) or (y!= -1):
            print(firstname)
            print(lastname)
            dataset.drop([i],inplace=True)
dataset = dataset.reset_index(drop=True)
l = len(dataset.Name)
# print(dataset.shape)
print ("People left in the group after the given constraints: ")
dataset
# Out:
# People left in the group after the given constraints:
#                      Name                            Email Year Department
# 0        Shankhadeep Giri   shankhadeepgiri.nsec@gmail.com  2nd        CSE
# 1               Faiz Alam             faiz276482@gmail.com  2nd         IT
# 2          Abhishek kumar           abhishek3368@gmail.com  2nd         IT
# 3              Vishwajeet             vish260199@gmail.com  2nd        CSE
# 4           Pradeep Kumar          pradeeproy732@gmail.com  2nd         IT
# 5             Vivek Kumar      sonusingh29051998@gmail.com  2nd        CSE
# 6         Tanmoy Sengupta          tasengupta405@gmail.com  2nd         EE
# 7           Gourab Santra   sabujgourabsantra123@gmail.com  2nd         EE
# 8        Subhasis Samanta     subhasissamanta074@gmail.com  2nd         EE
# 9              Sribas Das            dassribas44@gmail.com  2nd         EE
# 10          Sayantan Bera         sayantan.ronit@gmail.com  2nd        ECE
# ...

# %%
total_rows = dataset['Name'].count()
if(total_rows<30):
  print ("You are short of %(n)s people for DrAIvex to take place successfully." %{'n':30-total_rows})

# %%
civMech =dataset[dataset['Department'].isin(["CV","ME"])].count()
totCivMech =civMech.Name

if(totCivMech < int(total_rows/10)):
  print("You are short of %(p)s people from civil and mechnanical combined for DrAIvex to take place successfully."%{'p': int(total_rows/10)-totCivMech})
# Out:
# You are short of 9 people from civil and mechnanical combined for DrAIvex to take place successfully.
